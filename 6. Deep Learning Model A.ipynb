# %%
import sklearn.metrics as metrics
import pandas as pd
from sklearn.model_selection import train_test_split
from keras.preprocessing.text import Tokenizer
from sklearn.preprocessing import LabelEncoder
from keras.models import Sequential
from keras.layers import Dense,Dropout
from keras.optimizers import Adam
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from keras.utils import to_categorical
from sklearn.compose import ColumnTransformer
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
# Out:
# C:\Users\zxzx2\Anaconda3\lib\site-packages\pandas\compat\_optional.py:138: UserWarning: Pandas requires version '2.7.0' or newer of 'numexpr' (version '2.6.9' currently installed).
#   warnings.warn(msg, UserWarning)

# %%
df = pd.read_csv("epc_best20.csv")

# %%
# Split data into features and labels
X = df.drop("Current energy efficiency rating band", axis=1)
y = df["Current energy efficiency rating band"]
encoder = LabelEncoder()
y= encoder.fit_transform(y)

# One-hot encode labels
y = to_categorical(y, num_classes=7)

# %%
# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %%
# Define which columns are categorical and which are numerical
categorical_cols = ["Part 1 Construction Age Band", "Mechanical Ventilation", "Tenure", "Transaction Type",
                   "wall_insulation", "roof_insulation", "wall_type", "roof_type", "floor_type",
                   "windows_glazing", "low_lighting"]
numerical_cols = ["Total floor area (m²)", "Total current energy costs over 3 years (£)",
                  "Current hot water costs over 3 years (£)", "Part 1 Floor 0 Room Height",
                  "Low Energy Lighting %", "insulated_wall", "MMH_mains gas", "MHCS_programmer",
                  "SH_room heaters"]

# %%
# Create ColumnTransformer to handle different data types
preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), numerical_cols),
        ('cat', OneHotEncoder(), categorical_cols)])

# %%
# Fit and transform the data using the ColumnTransformer
X_train = preprocessor.fit_transform(X_train)
X_test = preprocessor.transform(X_test)

# %%
model = Sequential()
model.add(Dense(128, activation='relu', input_shape=(X_train.shape[1],)))
model.add(Dropout(0.5))  # Adding dropout to prevent overfitting
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))  # Adding dropout to prevent overfitting
model.add(Dense(7, activation='softmax'))

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
history = model.fit(X_train, y_train,validation_data = (X_test,y_test), epochs=100, batch_size=32)
# Out:
# Epoch 1/100
# C:\Users\zxzx2\Anaconda3\lib\site-packages\tensorflow\python\framework\indexed_slices.py:446: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/sequential_1/dense_3/embedding_lookup_sparse/Reshape_1:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/sequential_1/dense_3/embedding_lookup_sparse/Reshape:0", shape=(None, 128), dtype=float32), dense_shape=Tensor("gradient_tape/sequential_1/dense_3/embedding_lookup_sparse/Cast:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "shape. This may consume a large amount of memory." % value)
# 1193/1193 [==============================] - 6s 4ms/step - loss: 0.7961 - accuracy: 0.6884 - val_loss: 0.5299 - val_accuracy: 0.7936
# Epoch 2/100
# 1193/1193 [==============================] - 6s 5ms/step - loss: 0.5860 - accuracy: 0.7675 - val_loss: 0.4644 - val_accuracy: 0.8277
# Epoch 3/100
# 1193/1193 [==============================] - 7s 6ms/step - loss: 0.5217 - accuracy: 0.7978 - val_loss: 0.4295 - val_accuracy: 0.8333
# Epoch 4/100
# 1193/1193 [==============================] - 6s 5ms/step - loss: 0.4932 - accuracy: 0.8061 - val_loss: 0.4014 - val_accuracy: 0.8451
# Epoch 5/100
# 1193/1193 [==============================] - 6s 5ms/step - loss: 0.4689 - accuracy: 0.8169 - val_loss: 0.3829 - val_accuracy: 0.8516
# Epoch 6/100
# 1193/1193 [==============================] - 5s 4ms/step - loss: 0.4545 - accuracy: 0.8224 - val_loss: 0.3762 - val_accuracy: 0.8517
# Epoch 7/100
# 1193/1193 [==============================] - 8s 7ms/step - loss: 0.4427 - accuracy: 0.8272 - val_loss: 0.3753 - val_accuracy: 0.8567
# Epoch 8/100
# 1193/1193 [==============================] - 6s 5ms/step - loss: 0.4318 - accuracy: 0.8323 - val_loss: 0.3692 - val_accuracy: 0.8571
# Epoch 9/100
# 1193/1193 [==============================] - 7s 6ms/step - loss: 0.4278 - accuracy: 0.8313 - val_loss: 0.3627 - val_accuracy: 0.8614
# Epoch 10/100
# 1193/1193 [==============================] - 7s 6ms/step - loss: 0.4192 - accuracy: 0.8374 - val_loss: 0.3596 - val_accuracy: 0.8610
# Epoch 11/100
# 1193/1193 [==============================] - 6s 5ms/step - loss: 0.4128 - accuracy: 0.8386 - val_loss: 0.3582 - val_accuracy: 0.8606
# Epoch 12/100
# 1193/1193 [==============================] - 6s 5ms/step - loss: 0.4088 - accuracy: 0.8399 - val_loss: 0.3523 - val_accuracy: 0.8623
# Epoch 13/100
# 1193/1193 [==============================] - 10s 8ms/step - loss: 0.4031 - accuracy: 0.8433 - val_loss: 0.3492 - val_accuracy: 0.8631
# Epoch 14/100
# 1193/1193 [==============================] - 12s 10ms/step - loss: 0.4050 - accuracy: 0.8418 - val_loss: 0.3503 - val_accuracy: 0.8610
# Epoch 15/100
# 1193/1193 [==============================] - 9s 8ms/step - loss: 0.3974 - accuracy: 0.8447 - val_loss: 0.3565 - val_accuracy: 0.8625
# Epoch 16/100
# 1193/1193 [==============================] - 10s 8ms/step - loss: 0.3984 - accuracy: 0.8430 - val_loss: 0.3491 - val_accuracy: 0.8645
# Epoch 17/100
# 1193/1193 [==============================] - 6s 5ms/step - loss: 0.3949 - accuracy: 0.8453 - val_loss: 0.3487 - val_accuracy: 0.8655
# Epoch 18/100
# 1193/1193 [==============================] - 6s 5ms/step - loss: 0.3933 - accuracy: 0.8439 - val_loss: 0.3512 - val_accuracy: 0.8666
# Epoch 19/100
# 1193/1193 [==============================] - 6s 5ms/step - loss: 0.3924 - accuracy: 0.8461 - val_loss: 0.3447 - val_accuracy: 0.8698
# Epoch 20/100
# 1193/1193 [==============================] - 6s 5ms/step - loss: 0.3867 - accuracy: 0.8489 - val_loss: 0.3452 - val_accuracy: 0.8666
# Epoch 21/100
# 1193/1193 [==============================] - 7s 6ms/step - loss: 0.3803 - accuracy: 0.8516 - val_loss: 0.3467 - val_accuracy: 0.8674
# Epoch 22/100
# 1193/1193 [==============================] - 6s 5ms/step - loss: 0.3863 - accuracy: 0.8486 - val_loss: 0.3437 - val_accuracy: 0.8679
# Epoch 23/100
# 1193/1193 [==============================] - 7s 6ms/step - loss: 0.3830 - accuracy: 0.8500 - val_loss: 0.3477 - val_accuracy: 0.8696
# Epoch 24/100
# 1193/1193 [==============================] - 7s 6ms/step - loss: 0.3816 - accuracy: 0.8486 - val_loss: 0.3413 - val_accuracy: 0.8684
# Epoch 25/100
# 1193/1193 [==============================] - 8s 7ms/step - loss: 0.3772 - accuracy: 0.8521 - val_loss: 0.3411 - val_accuracy: 0.8705
# Epoch 26/100
# 1193/1193 [==============================] - 5s 5ms/step - loss: 0.3798 - accuracy: 0.8520 - val_loss: 0.3415 - val_accuracy: 0.8695
# Epoch 27/100
# 1193/1193 [==============================] - 6s 5ms/step - loss: 0.3761 - accuracy: 0.8538 - val_loss: 0.3389 - val_accuracy: 0.8711
# Epoch 28/100
# 1193/1193 [==============================] - 8s 6ms/step - loss: 0.3747 - accuracy: 0.8519 - val_loss: 0.3350 - val_accuracy: 0.8734
# Epoch 29/100
# 1193/1193 [==============================] - 9s 7ms/step - loss: 0.3722 - accuracy: 0.8568 - val_loss: 0.3402 - val_accuracy: 0.8705
# Epoch 30/100
# 1193/1193 [==============================] - 6s 5ms/step - loss: 0.3717 - accuracy: 0.8554 - val_loss: 0.3413 - val_accuracy: 0.8724
# Epoch 31/100
# 1193/1193 [==============================] - 6s 5ms/step - loss: 0.3697 - accuracy: 0.8555 - val_loss: 0.3383 - val_accuracy: 0.8690
# Epoch 32/100
# 1193/1193 [==============================] - 5s 4ms/step - loss: 0.3642 - accuracy: 0.8568 - val_loss: 0.3373 - val_accuracy: 0.8698
# Epoch 33/100
# 1193/1193 [==============================] - 6s 5ms/step - loss: 0.3657 - accuracy: 0.8570 - val_loss: 0.3424 - val_accuracy: 0.8685
# Epoch 34/100
# 1193/1193 [==============================] - 6s 5ms/step - loss: 0.3666 - accuracy: 0.8571 - val_loss: 0.3442 - val_accuracy: 0.8692
# Epoch 35/100
# 1193/1193 [==============================] - 7s 6ms/step - loss: 0.3656 - accuracy: 0.8579 - val_loss: 0.3387 - val_accuracy: 0.8715
# Epoch 36/100
# 1193/1193 [==============================] - 6s 5ms/step - loss: 0.3652 - accuracy: 0.8562 - val_loss: 0.3352 - val_accuracy: 0.8720
# Epoch 37/100
# 1193/1193 [==============================] - 6s 5ms/step - loss: 0.3645 - accuracy: 0.8572 - val_loss: 0.3410 - val_accuracy: 0.8693
# Epoch 38/100
# 1193/1193 [==============================] - 7s 6ms/step - loss: 0.3624 - accuracy: 0.8592 - val_loss: 0.3342 - val_accuracy: 0.8724
# Epoch 39/100
# 1193/1193 [==============================] - 6s 5ms/step - loss: 0.3623 - accuracy: 0.8570 - val_loss: 0.3379 - val_accuracy: 0.8701
# Epoch 40/100
# 1193/1193 [==============================] - 7s 6ms/step - loss: 0.3615 - accuracy: 0.8598 - val_loss: 0.3367 - val_accuracy: 0.8726
# Epoch 41/100
# 1193/1193 [==============================] - 6s 5ms/step - loss: 0.3607 - accuracy: 0.8587 - val_loss: 0.3483 - val_accuracy: 0.8638
# Epoch 42/100
# 1193/1193 [==============================] - 7s 6ms/step - loss: 0.3610 - accuracy: 0.8583 - val_loss: 0.3359 - val_accuracy: 0.8738
# Epoch 43/100
# 1193/1193 [==============================] - 7s 5ms/step - loss: 0.3605 - accuracy: 0.8590 - val_loss: 0.3357 - val_accuracy: 0.8735
# Epoch 44/100
# 1193/1193 [==============================] - 6s 5ms/step - loss: 0.3543 - accuracy: 0.8616 - val_loss: 0.3361 - val_accuracy: 0.8727
# Epoch 45/100
# 1193/1193 [==============================] - 6s 5ms/step - loss: 0.3600 - accuracy: 0.8586 - val_loss: 0.3370 - val_accuracy: 0.8749
# Epoch 46/100
# 1193/1193 [==============================] - 6s 5ms/step - loss: 0.3551 - accuracy: 0.8601 - val_loss: 0.3365 - val_accuracy: 0.8698
# Epoch 47/100
# 1193/1193 [==============================] - 6s 5ms/step - loss: 0.3561 - accuracy: 0.8595 - val_loss: 0.3392 - val_accuracy: 0.8727
# Epoch 48/100
# 1193/1193 [==============================] - 6s 5ms/step - loss: 0.3535 - accuracy: 0.8629 - val_loss: 0.3427 - val_accuracy: 0.8701
# Epoch 49/100
# 1193/1193 [==============================] - 6s 5ms/step - loss: 0.3544 - accuracy: 0.8594 - val_loss: 0.3391 - val_accuracy: 0.8660
# Epoch 50/100
# 1193/1193 [==============================] - 6s 5ms/step - loss: 0.3540 - accuracy: 0.8629 - val_loss: 0.3376 - val_accuracy: 0.8708
# Epoch 51/100
# 1193/1193 [==============================] - 6s 5ms/step - loss: 0.3564 - accuracy: 0.8615 - val_loss: 0.3348 - val_accuracy: 0.8741
# Epoch 52/100
# 1193/1193 [==============================] - 6s 5ms/step - loss: 0.3534 - accuracy: 0.8629 - val_loss: 0.3344 - val_accuracy: 0.8723
# Epoch 53/100
# 1193/1193 [==============================] - 6s 5ms/step - loss: 0.3506 - accuracy: 0.8622 - val_loss: 0.3373 - val_accuracy: 0.8757
# Epoch 54/100
# 1193/1193 [==============================] - 6s 5ms/step - loss: 0.3532 - accuracy: 0.8622 - val_loss: 0.3478 - val_accuracy: 0.8657
# Epoch 55/100
# 1193/1193 [==============================] - 6s 5ms/step - loss: 0.3504 - accuracy: 0.8628 - val_loss: 0.3360 - val_accuracy: 0.8741
# Epoch 56/100
# 1193/1193 [==============================] - 7s 6ms/step - loss: 0.3505 - accuracy: 0.8637 - val_loss: 0.3358 - val_accuracy: 0.8758
# Epoch 57/100
# 1193/1193 [==============================] - 6s 5ms/step - loss: 0.3513 - accuracy: 0.8622 - val_loss: 0.3396 - val_accuracy: 0.8673
# Epoch 58/100
# 1193/1193 [==============================] - 6s 5ms/step - loss: 0.3496 - accuracy: 0.8629 - val_loss: 0.3339 - val_accuracy: 0.8749
# Epoch 59/100
# 1193/1193 [==============================] - 6s 5ms/step - loss: 0.3484 - accuracy: 0.8643 - val_loss: 0.3342 - val_accuracy: 0.8755
# Epoch 60/100
# 1193/1193 [==============================] - 6s 5ms/step - loss: 0.3484 - accuracy: 0.8626 - val_loss: 0.3365 - val_accuracy: 0.8742
# Epoch 61/100
# 1193/1193 [==============================] - 6s 5ms/step - loss: 0.3490 - accuracy: 0.8623 - val_loss: 0.3386 - val_accuracy: 0.8738
# Epoch 62/100
# 1193/1193 [==============================] - 6s 5ms/step - loss: 0.3491 - accuracy: 0.8637 - val_loss: 0.3341 - val_accuracy: 0.8764
# Epoch 63/100
# 1193/1193 [==============================] - 6s 5ms/step - loss: 0.3498 - accuracy: 0.8618 - val_loss: 0.3346 - val_accuracy: 0.8739
# Epoch 64/100
# 1193/1193 [==============================] - 6s 5ms/step - loss: 0.3410 - accuracy: 0.8639 - val_loss: 0.3442 - val_accuracy: 0.8714
# Epoch 65/100
# 1193/1193 [==============================] - 6s 5ms/step - loss: 0.3476 - accuracy: 0.8637 - val_loss: 0.3388 - val_accuracy: 0.8704
# Epoch 66/100
# 1193/1193 [==============================] - 6s 5ms/step - loss: 0.3467 - accuracy: 0.8649 - val_loss: 0.3371 - val_accuracy: 0.8712
# Epoch 67/100
# 1193/1193 [==============================] - 6s 5ms/step - loss: 0.3471 - accuracy: 0.8658 - val_loss: 0.3395 - val_accuracy: 0.8705
# Epoch 68/100
# 1193/1193 [==============================] - 7s 6ms/step - loss: 0.3436 - accuracy: 0.8648 - val_loss: 0.3324 - val_accuracy: 0.8752
# Epoch 69/100
# 1193/1193 [==============================] - 6s 5ms/step - loss: 0.3418 - accuracy: 0.8649 - val_loss: 0.3359 - val_accuracy: 0.8720
# Epoch 70/100
# 1193/1193 [==============================] - 6s 5ms/step - loss: 0.3443 - accuracy: 0.8656 - val_loss: 0.3360 - val_accuracy: 0.8741
# Epoch 71/100
# 1193/1193 [==============================] - 10s 8ms/step - loss: 0.3455 - accuracy: 0.8654 - val_loss: 0.3380 - val_accuracy: 0.8739
# Epoch 72/100
# 1193/1193 [==============================] - 11s 9ms/step - loss: 0.3438 - accuracy: 0.8635 - val_loss: 0.3432 - val_accuracy: 0.8741
# Epoch 73/100
# 1193/1193 [==============================] - 12s 10ms/step - loss: 0.3454 - accuracy: 0.8641 - val_loss: 0.3396 - val_accuracy: 0.8752
# Epoch 74/100
# 1193/1193 [==============================] - 11s 9ms/step - loss: 0.3430 - accuracy: 0.8644 - val_loss: 0.3329 - val_accuracy: 0.8742
# Epoch 75/100
# 1193/1193 [==============================] - 6s 5ms/step - loss: 0.3392 - accuracy: 0.8675 - val_loss: 0.3374 - val_accuracy: 0.8736
# Epoch 76/100
# 1193/1193 [==============================] - 6s 5ms/step - loss: 0.3461 - accuracy: 0.8657 - val_loss: 0.3400 - val_accuracy: 0.8681
# Epoch 77/100
# 1193/1193 [==============================] - 6s 5ms/step - loss: 0.3411 - accuracy: 0.8677 - val_loss: 0.3337 - val_accuracy: 0.8753
# Epoch 78/100
# 1193/1193 [==============================] - 5s 4ms/step - loss: 0.3385 - accuracy: 0.8671 - val_loss: 0.3421 - val_accuracy: 0.8712
# Epoch 79/100
# 1193/1193 [==============================] - 6s 5ms/step - loss: 0.3430 - accuracy: 0.8652 - val_loss: 0.3332 - val_accuracy: 0.8741
# Epoch 80/100
# 1193/1193 [==============================] - 8s 7ms/step - loss: 0.3366 - accuracy: 0.8664 - val_loss: 0.3377 - val_accuracy: 0.8730
# Epoch 81/100
# 1193/1193 [==============================] - 9s 7ms/step - loss: 0.3390 - accuracy: 0.8683 - val_loss: 0.3363 - val_accuracy: 0.8714
# Epoch 82/100
# 1193/1193 [==============================] - 5s 4ms/step - loss: 0.3396 - accuracy: 0.8648 - val_loss: 0.3348 - val_accuracy: 0.8774
# Epoch 83/100
# 1193/1193 [==============================] - 6s 5ms/step - loss: 0.3385 - accuracy: 0.8648 - val_loss: 0.3337 - val_accuracy: 0.8756
# Epoch 84/100
# 1193/1193 [==============================] - 6s 5ms/step - loss: 0.3426 - accuracy: 0.8678 - val_loss: 0.3313 - val_accuracy: 0.8784
# Epoch 85/100
# 1193/1193 [==============================] - 6s 5ms/step - loss: 0.3398 - accuracy: 0.8675 - val_loss: 0.3333 - val_accuracy: 0.8769
# Epoch 86/100
# 1193/1193 [==============================] - 6s 5ms/step - loss: 0.3445 - accuracy: 0.8662 - val_loss: 0.3359 - val_accuracy: 0.8765
# Epoch 87/100
# 1193/1193 [==============================] - 6s 5ms/step - loss: 0.3355 - accuracy: 0.8673 - val_loss: 0.3422 - val_accuracy: 0.8708
# Epoch 88/100
# 1193/1193 [==============================] - 6s 5ms/step - loss: 0.3362 - accuracy: 0.8683 - val_loss: 0.3330 - val_accuracy: 0.8724
# Epoch 89/100
# 1193/1193 [==============================] - 6s 5ms/step - loss: 0.3408 - accuracy: 0.8683 - val_loss: 0.3385 - val_accuracy: 0.8700
# Epoch 90/100
# 1193/1193 [==============================] - 6s 5ms/step - loss: 0.3391 - accuracy: 0.8692 - val_loss: 0.3357 - val_accuracy: 0.8761
# Epoch 91/100
# 1193/1193 [==============================] - 6s 5ms/step - loss: 0.3345 - accuracy: 0.8690 - val_loss: 0.3374 - val_accuracy: 0.8739
# Epoch 92/100
# 1193/1193 [==============================] - 6s 5ms/step - loss: 0.3368 - accuracy: 0.8686 - val_loss: 0.3360 - val_accuracy: 0.8750
# Epoch 93/100
# 1193/1193 [==============================] - 7s 5ms/step - loss: 0.3353 - accuracy: 0.8686 - val_loss: 0.3394 - val_accuracy: 0.8754
# Epoch 94/100
# 1193/1193 [==============================] - 5s 4ms/step - loss: 0.3387 - accuracy: 0.8688 - val_loss: 0.3432 - val_accuracy: 0.8717
# Epoch 95/100
# 1193/1193 [==============================] - 7s 5ms/step - loss: 0.3411 - accuracy: 0.8664 - val_loss: 0.3401 - val_accuracy: 0.8755
# Epoch 96/100
# 1193/1193 [==============================] - 5s 4ms/step - loss: 0.3352 - accuracy: 0.8700 - val_loss: 0.3412 - val_accuracy: 0.8755
# Epoch 97/100
# 1193/1193 [==============================] - 6s 5ms/step - loss: 0.3339 - accuracy: 0.8699 - val_loss: 0.3400 - val_accuracy: 0.8731
# Epoch 98/100
# 1193/1193 [==============================] - 6s 5ms/step - loss: 0.3370 - accuracy: 0.8681 - val_loss: 0.3338 - val_accuracy: 0.8761
# Epoch 99/100
# 1193/1193 [==============================] - 6s 5ms/step - loss: 0.3356 - accuracy: 0.8692 - val_loss: 0.3398 - val_accuracy: 0.8684
# Epoch 100/100
# 1193/1193 [==============================] - 6s 5ms/step - loss: 0.3380 - accuracy: 0.8692 - val_loss: 0.3429 - val_accuracy: 0.8720

# %%
# Evaluate model
score = model.evaluate(X_test, y_test)
print("Test loss: ", score[0])
print("Test accuracy: ", score[1])
# Out:
# 511/511 [==============================] - 2s 3ms/step - loss: 0.3429 - accuracy: 0.8720
# Test loss:  0.3429132103919983
# Test accuracy:  0.8720411062240601

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper right')
plt.show()

# %%
# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
from sklearn.metrics import roc_auc_score, roc_curve
import matplotlib.pyplot as plt

# Compute the predicted probabilities for each class
y_pred_proba = model.predict(X_test)

# Compute the average AUC score across all classes
auc = roc_auc_score(y_test, y_pred_proba, multi_class='ovr')
print('Average AUC:', auc)

# Compute the FPR and TPR for each class
fpr = dict()
tpr = dict()
for i in range(7):
    fpr[i], tpr[i], _ = roc_curve(y_test[:, i], y_pred_proba[:, i])

# Plot the ROC curve for each class
plt.figure()
for i in range(7):
    plt.plot(fpr[i], tpr[i], label='ROC curve of class {}'.format(i))
plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC curves for multiclass output')
plt.legend(loc="lower right")
plt.show()
# Out:
# 511/511 [==============================] - 1s 2ms/step
# Average AUC: 0.9820758213879965

# %%
# Make predictions on the test set
y_pred_proba = model.predict(X_test)
y_pred = y_pred_proba.argmax(axis=1)

#convert one hot encoded y_test to numerical format
y_test = y_test.argmax(axis=1)

# Evaluate model
print("Accuracy: ", accuracy_score(y_test, y_pred))
print("Precision: ", precision_score(y_test, y_pred, average='weighted'))
print("Recall: ", recall_score(y_test, y_pred, average='weighted'))
print("F1 Score: ", f1_score(y_test, y_pred, average='weighted'))
# Out:
# 511/511 [==============================] - 1s 2ms/step
# Accuracy:  0.8720411034314025
# Precision:  0.8702419931398974
# Recall:  0.8720411034314025
# F1 Score:  0.8677522624710042

# %%
    import numpy as np
    rmse = np.sqrt(metrics.mean_squared_error(y_test, y_pred)) 
    r2 = metrics.r2_score(y_test, y_pred)
    print(f"\nr2: {rmse}") ##print mean square error and r2
    print(f"\nRMSE: {rmse}")
# Out:
# r2: 0.38861087338362316
#
# RMSE: 0.38861087338362316

# %%
def plot_conf_mat(y_test, y_pred):
    '''prints the confusion matrix'''
    from sklearn.metrics import confusion_matrix
    cm = confusion_matrix(y_test, y_pred)

    fig, ax = plt.subplots(figsize=(5,5))
    ax.matshow(cm, cmap=plt.cm.Blues, alpha=0.8)
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            ax.text(x=j, y=i,s=cm[i, j], va='center', ha='center', size='small')

    plt.xlabel('Predictions', fontsize=10)
    plt.ylabel('Actuals', fontsize=10)
    plt.title('Confusion Matrix', fontsize=10)
    plt.show()
    return

# %%
plot_conf_mat(y_test, y_pred)
